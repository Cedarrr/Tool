# %%
# 行专列：https://www.cnblogs.com/traditional/p/11967360.html
# 计算行列总和：https://blog.csdn.net/weixin_43745169/article/details/103372098

import pandas as pd
#from Texttable import texttable

#import xlwt as xw

START_DATE=221024
END_DATE=221030
DESIGNER=str(START_DATE)+'-'+str(END_DATE)

data=pd.read_excel("video-data2.xlsx")
data=data[data['制作时间']>=START_DATE]
data=data[data['制作时间']<=END_DATE]

data=data.rename(columns={'设计师':DESIGNER})

writer=pd.ExcelWriter('output.xlsx')

#get data_class(in_data,column_name):
column_name='素材类型'
in_data=data
in_data=in_data.groupby([DESIGNER,column_name])
name_data=in_data['素材名'].apply(lambda x: "、".join(list(set(x.str.cat(sep=',').split(','))))).unstack()
count_data=in_data['素材名'].count().unstack()
count_data['总计']=count_data.apply(lambda x: x.sum(),axis=1)
count_data.loc['总计']=count_data.apply(lambda x: x.sum(),axis=0)

name_data.to_excel(writer,'name')
count_data.to_excel(writer,'count')
    

#data_class(data,'素材类型')


writer.save()


print('done')
# Out:
# done

# %%
# 参考
# https://blog.csdn.net/baidu_41797613/article/details/121555351

import pandas as pd
import numpy as np




# 1、process video file, get the name of each category in period (output to different files)
type_pd=pd.DataFrame()

video=pd.read_excel("video-data2.xlsx")
market=pd.read_excel("market-221027.xlsx")

START_DATE=221017
END_DATE=221023
CATEGORY='开头'
OUTPUT_NAME=CATEGORY+"-VIDEO-ANALYSIS.xlsx"
# '用户心理需求'
# '开头'
# '素材类型'
# '主卖点'
# '副卖点'
# '创意形式'
# '创意架构'
# '游戏付费点'
video = video[video['制作时间'] >= START_DATE]
video = video[video['制作时间'] <= END_DATE]
video.fillna('无',inplace=True)
video_category_list=video[CATEGORY].unique()

writer=pd.ExcelWriter(OUTPUT_NAME)

for TYPE in video_category_list:

    video_type = video[video[CATEGORY] == TYPE]
    video_name_list=video_type['素材名'].unique()

    new = pd.DataFrame()

    for i in video_name_list:
        if (market[market['素材名'].str.contains(i)].empty == False):
            #new=new.append(market[market['素材名']==i])
            new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
            new['TYPE']=TYPE
    type_pd=type_pd.append(new)

    new.to_excel(writer,sheet_name=TYPE,index=False)

type_pd.to_excel(writer,sheet_name='ALL',index=False)

#pt=pd.pivot_table(type_pd,index=[u'素材名',u'媒体',u'端'],aggfunc=np.sum,margins=False)
def get_pt(pt):
    new_pt = pd.DataFrame()
    new_pt['消耗'] = pt['消耗']

    new_pt['激活成本'] = round(pt['消耗'] / pt['激活数'], 0)
    new_pt['付费成本'] = round(pt['消耗'] / pt['首日付费人数'], 0)
    new_pt['点击率（%）'] = round(pt['点击数'] / pt['曝光数'], 4) * 100
    new_pt['转化率（%）'] = round(pt['激活数'] / pt['点击数'], 3) * 100
    new_pt['注册率（%）'] = round(pt['注册数'] / pt['激活数'], 3) * 100
    new_pt['首日付费率（%）'] = round(pt['首日付费人数'] / pt['激活数'], 3) * 100
    new_pt['次留率（%）'] = round(pt['次留数'] / pt['激活数'], 3) * 100
    new_pt['首日ROI（%）'] = round(pt['首日付费金额'] / pt['消耗'], 3) * 100
    new_pt['三日ROI（%）'] = round(pt['F3付费金额'] / pt['消耗'], 3) * 100
    new_pt['3/1涨幅'] = round(new_pt['三日ROI（%）'] / new_pt['首日ROI（%）'], 2)
    
    new_pt['25%进度播放率%']=round(pt['25%进度播放数'] /pt['曝光数'], 3) * 100
    new_pt['50%进度播放率%']=round(pt['50%进度播放数'] /pt['曝光数'], 3) * 100
    new_pt['75%进度播放率%']=round(pt['75%进度播放数'] /pt['曝光数'], 3) * 100
    new_pt['完播率%']=round(pt['99%进度播放数'] /pt['曝光数'], 3) * 100
    new_pt['有效播放率%']=round(pt['有效播放数'] /pt['曝光数'], 3) * 100

#     new_pt['点击率（%）'] = round(pt['点击数'] / pt['曝光数'], 4) 
#     new_pt['转化率（%）'] = round(pt['激活数'] / pt['点击数'], 3) 
#     new_pt['注册率（%）'] = round(pt['注册数'] / pt['激活数'], 3) 
#     new_pt['首日付费率（%）'] = round(pt['首日付费人数'] / pt['激活数'], 3) 
#     new_pt['次留率（%）'] = round(pt['次留数'] / pt['激活数'], 3) 
#     new_pt['首日ROI（%）'] = round(pt['首日付费金额'] / pt['消耗'], 3)
#     new_pt['三日ROI（%）'] = round(pt['F3付费金额'] / pt['消耗'], 3) 
#     new_pt['3/1涨幅'] = round(new_pt['三日ROI（%）'] / new_pt['首日ROI（%）'], 2)
    
#     new_pt['25%进度播放率%']=round(pt['25%进度播放数'] /pt['曝光数'], 3) 
#     new_pt['50%进度播放率%']=round(pt['50%进度播放数'] /pt['曝光数'], 3) 
#     new_pt['75%进度播放率%']=round(pt['75%进度播放数'] /pt['曝光数'], 3) 
#     new_pt['完播率%']=round(pt['99%进度播放数'] /pt['曝光数'], 3) 
#     new_pt['有效播放率%']=round(pt['有效播放数'] /pt['曝光数'], 3) 
    return new_pt

pt_video=pd.pivot_table(type_pd,index=[u'媒体',u'端',u'TYPE',u'素材名'],aggfunc=np.sum,margins=False)
new_pt_video=get_pt(pt_video)

pt_all_video=pd.pivot_table(type_pd,index=[u'媒体',u'端',u'TYPE'],aggfunc=np.sum,margins=False)
new_pt_all_video=get_pt(pt_all_video)



# pt_market=pd.pivot_table(market,index=[u'端',u'素材名'],aggfunc=np.sum,margins=True)
# new_pt_market=get_pt(pt_market)



# set style
new_pt_video_style=new_pt_video.fillna(0).style.background_gradient(cmap='PuBu')\
                                            .applymap(lambda x:"background-color:#000000"，subset=['激活成本'])
                                            .applymap(lambda x:"background-color:#000000"，subset=['付费成本'])
                                            .applymap(lambda x:"background-color:#000000"，subset=['3/1涨幅'])




# pt.to_excel(writer,sheet_name='pt',index=True)
new_pt_video.to_excel(writer,sheet_name='pt-video',index=True)
new_pt_all_video.to_excel(writer,sheet_name='new_pt_all_video',index=True)
new_pt_video_style.to_excel(writer,sheet_name='style',index=True)
# new_pt_market.to_excel(writer,sheet_name='pt-market',index=True)




writer.save()

# all_data = pd.pivot_table(new, index=['month'], aggfunc=np.sum, margins=True)
# print(all_data)
print('done')
# Out:
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\3013413375.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   type_pd=type_pd.append(new)
# D:\soft\anaconda-4\lib\site-packages\pandas\io\formats\style.py:3558: RuntimeWarning: invalid value encountered in double_scalars
#   norm = mpl.colors.Normalize(smin - (rng * low), smax + (rng * high))
# done

# %%
# 参考
# https://blog.csdn.net/baidu_41797613/article/details/121555351

import pandas as pd
import numpy as np
# 1、process video file, get the name of each category in period (output to different files)
video=pd.read_excel("video.xlsx")
market=pd.read_excel("market-220929.xlsx")
START_DATE = 220815
END_DATE = 220821

video = video[video['制作时间'] >= START_DATE]
video = video[video['制作时间'] <= END_DATE]
video_category_list=video['素材类型'].unique()

writer=pd.ExcelWriter('output.xlsx')
type_pd=pd.DataFrame()
for TYPE in video_category_list:
    video_type = video[video['素材类型'] == TYPE]
    video_name_list=video_type['素材名'].unique()
    new = pd.DataFrame()

    for i in video_name_list:
        if (market[market['素材名'].str.contains(i)].empty==False):
            new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
            new['TYPE']=TYPE


    new.to_excel(writer,sheet_name=TYPE,index=False)


writer.save()

# all_data = pd.pivot_table(new, index=['month'], aggfunc=np.sum, margins=True)
# print(all_data)
print('done')
# Out:
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_25332\2181068170.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_25332\2181068170.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 18>()
#      21 new = pd.DataFrame()
#      23 for i in video_name_list:
# ---> 24     if (market[market['素材名'].str.contains(i)].empty==False):
#      25         new=new.append(market[market['素材名'].str.contains(i)],ignore_index=True)
#      26         new['TYPE']=TYPE
#
# File D:\soft\anaconda-4\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File D:\soft\anaconda-4\lib\site-packages\pandas\core\strings\accessor.py:1214, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1089 @forbid_nonstring_types(["bytes"])
#    1090 def contains(self, pat, case=True, flags=0, na=None, regex=True):
#    1091     r"""
#    1092     Test if pattern or regex is contained within a string of a Series or Index.
#    1093
#    (...)
#    1212     dtype: bool
#    1213     """
# -> 1214     if regex and re.compile(pat).groups:
#    1215         warnings.warn(
#    1216             "This pattern is interpreted as a regular expression, and has "
#    1217             "match groups. To actually get the groups, use str.extract.",
#    1218             UserWarning,
#    1219             stacklevel=find_stack_level(),
#    1220         )
#    1222     result = self._data.array._str_contains(pat, case, flags, na, regex)
#
# File D:\soft\anaconda-4\lib\re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File D:\soft\anaconda-4\lib\re.py:303, in _compile(pattern, flags)
#     301     return pattern
#     302 if not sre_compile.isstring(pattern):
# --> 303     raise TypeError("first argument must be string or compiled pattern")
#     304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#
# TypeError: first argument must be string or compiled pattern

# %%
# 朝霞素材统计报表快速筛选

import pandas as pd
import numpy as np

SUCAI_NAME= '头条-安卓'
# '头条-安卓'
# '头条-ios'
# '快手-安卓'
# '快手-ios'
SUCAI_LOC=SUCAI_NAME+'.xlsx'
OUTPUT_NAME=SUCAI_NAME+'-output.xlsx'

data=pd.read_excel(SUCAI_LOC)
out=pd.DataFrame()

data=data.drop(data[data['素材名']=='汇总'].index)

MEITI=SUCAI_NAME.split('-')[0]
DUAN=SUCAI_NAME.split('-')[1]
data['媒体']=MEITI
data['端']=DUAN


out['媒体']=data['媒体']
out['端']=data['端']
out['cpsid']=0
out['日期']=0


out['素材名']=data['素材名'].str.replace('.mp4','')
out['消耗']=data['花费']
out['曝光数']=data['展示数']
out['点击数']=data['点击数']
out['25%进度播放数']=0
out['50%进度播放数']=0
out['75%进度播放数']=0
out['99%进度播放数']=0
out['有效播放数']=0

out['激活数']=data['累计激活数']
out['注册数']=data['累计注册数']
out['首日付费人数']=data['首日付费数']
out['次留']=0
out['首日付费金额']=data['首日充值'].str.replace(',','').astype(float)*2
out['F3付费金额']=data['3日充值'].str.replace(',','').astype(float)*2
out['累计付费金额']=data['累计充值'].str.replace(',','').astype(float)*2
writer=pd.ExcelWriter(OUTPUT_NAME)
out.to_excel(writer,index=False)
writer.save()
print('done')
# Out:
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_17572\3993301665.py:30: FutureWarning: The default value of regex will change from True to False in a future version.
#   out['素材名']=data['素材名'].str.replace('.mp4','')
# done

# %%
# 朝霞素材统计报表快速筛选

import pandas as pd
import numpy as np
data_list=['头条-安卓','头条-ios','快手-安卓','快手-ios']
df=pd.DataFrame()

def get_list(SUCAI_NAME):

    SUCAI_LOC=SUCAI_NAME+'.xlsx'
    OUTPUT_NAME=SUCAI_NAME+'-output.xlsx'

    data=pd.read_excel(SUCAI_LOC)
    out=pd.DataFrame()

    data=data.drop(data[data['素材名']=='汇总'].index)
    data=data.drop(data[(data['消耗']=='0.00')|(data['消耗']==0)].index)

    MEITI=SUCAI_NAME.split('-')[0]
    DUAN=SUCAI_NAME.split('-')[1]
    data['媒体']=MEITI
    data['端']=DUAN


    out['媒体']=data['媒体']
    out['端']=data['端']
    out['cpsid']=0
    out['日期']='221024-221030'


    out['素材名']=data['素材名'].str.replace('.mp4','')
    #out['消耗']=data['消耗'].str.replace(',','').astype(float)
    out['消耗']=data['消耗']
    out['曝光数']=data['展示数']
    out['点击数']=data['点击数']
    out['25%进度播放数']=data['25%进度播放']
    out['50%进度播放数']=data['50%进度播放']
    out['75%进度播放数']=data['75%进度播放']
    out['99%进度播放数']=data['99%进度播放']
    out['有效播放数']=data['有效播放数']

    out['激活数']=data['广告激活数-MP']
    out['注册数']=data['广告注册数-MP']
    out['首日付费人数']=data['首日广告付费账号数-MP']
    # out['次留数']=data['次留数-MP'].str.strip('%').astype(float)/100
    # out['首日付费金额']=data['首日广告付费金额-MP'].astype(str).str.replace(',','').astype(float)*2
    # out['F3付费金额']=data['3日广告付费金额-MP'].astype(str).str.replace(',','').astype(float)*2
    # out['累计付费金额']=data['广告新增付费金额-MP'].astype(str).str.replace(',','').astype(float)*2
    out['次留数']=data['次留数-MP']
    out['首日付费金额']=data['首日广告付费金额-MP'].astype(str).str.replace(',','').astype(float)*2
    out['F3付费金额']=data['3日广告付费金额-MP'].astype(str).str.replace(',','').astype(float)*2
    out['累计付费金额']=data['广告新增付费金额-MP'].astype(str).str.replace(',','').astype(float)*2
    
    writer=pd.ExcelWriter(OUTPUT_NAME)
    out.to_excel(writer,index=False)
    writer.save()
    
    print(SUCAI_NAME,'done')


for i in data_list:
    get_list(i)
    
print("completed")
# Out:
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\4102806967.py:31: FutureWarning: The default value of regex will change from True to False in a future version.
#   out['素材名']=data['素材名'].str.replace('.mp4','')
# 头条-安卓 done
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\4102806967.py:31: FutureWarning: The default value of regex will change from True to False in a future version.
#   out['素材名']=data['素材名'].str.replace('.mp4','')
# 头条-ios done
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\4102806967.py:31: FutureWarning: The default value of regex will change from True to False in a future version.
#   out['素材名']=data['素材名'].str.replace('.mp4','')
# 快手-安卓 done
# 快手-ios done
# completed
# C:\Users\liumeishan1\AppData\Local\Temp\ipykernel_21540\4102806967.py:31: FutureWarning: The default value of regex will change from True to False in a future version.
#   out['素材名']=data['素材名'].str.replace('.mp4','')

# %%
import pandas as pd
video=pd.read_excel("video-data2.xlsx")
print(video.head())
video.fillna('无',inplace=True)
print(video.head())
# Out:
#   制作情况  文案时间       素材名   文案   副本  用户行为 用户心理需求 创意形式 创意架构 游戏付费点  ...  主卖点  副卖点  \
# 0    是   NaN  翠竹洞 尊贵的T  NaN  翠竹洞   NaN    NaN  NaN  NaN   NaN  ...  NaN  NaN
# 1    是   NaN     英雄级魔宫  NaN   魔宫   NaN    NaN  NaN  NaN   NaN  ...  NaN  NaN
# 2    是   NaN  阴风洞 手欠的我  NaN  阴风洞   NaN    NaN  NaN  NaN   NaN  ...  NaN  NaN
# 3    是   NaN      通关姜问  NaN   魔宫   NaN    NaN  NaN  NaN   NaN  ...  NaN  NaN
# 4    是   NaN      第8次本  NaN   魔宫   NaN    NaN  NaN  NaN   NaN  ...  NaN  NaN
#
#     职业  设计师      制作时间   画面  评分   备注  Unnamed: 20 Unnamed: 21
# 0  NaN  杨卫卫  220427.0  NaN NaN  NaN          NaN         NaN
# 1  NaN  余福承  220428.0  NaN NaN  NaN          NaN         NaN
# 2  NaN  杨卫卫  220428.0  NaN NaN  NaN          NaN         NaN
# 3  NaN  董芳婧  220428.0  NaN NaN  NaN          NaN         NaN
# 4  NaN  许艳芳  220428.0  NaN NaN  NaN          NaN         NaN
#
# [5 rows x 22 columns]
#   制作情况 文案时间       素材名 文案   副本 用户行为 用户心理需求 创意形式 创意架构 游戏付费点  ... 主卖点 副卖点 职业  \
# 0    是    无  翠竹洞 尊贵的T  无  翠竹洞    无      无    无    无     无  ...   无   无  无
# 1    是    无     英雄级魔宫  无   魔宫    无      无    无    无     无  ...   无   无  无
# 2    是    无  阴风洞 手欠的我  无  阴风洞    无      无    无    无     无  ...   无   无  无
# 3    是    无      通关姜问  无   魔宫    无      无    无    无     无  ...   无   无  无
# 4    是    无      第8次本  无   魔宫    无      无    无    无     无  ...   无   无  无
#
#    设计师      制作时间 画面 评分 备注 Unnamed: 20 Unnamed: 21
# 0  杨卫卫  220427.0  无  无  无           无           无
# 1  余福承  220428.0  无  无  无           无           无
# 2  杨卫卫  220428.0  无  无  无           无           无
# 3  董芳婧  220428.0  无  无  无           无           无
# 4  许艳芳  220428.0  无  无  无           无           无
#
# [5 rows x 22 columns]
